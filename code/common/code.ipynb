# %%
from pdfminer.high_level import extract_pages
for page_layout in extract_pages(r"C:\Users\Namita\OneDrive\Desktop\major_project\code\data\Teacher Resume Samples .pdf"):
    for element in page_layout:
        print(element)
# Out:
# <LTTextBoxHorizontal(0) 36.520,749.655,377.106,760.695 'Please note: Sample resumes are for reference only and should not be copied \n'>
# <LTTextBoxHorizontal(1) 223.018,705.495,392.782,734.167 'Name \nStreet | City State, Zip | Phone | Email \n'>
# <LTTextBoxHorizontal(2) 36.520,652.215,222.579,690.888 'CERTIFICATION \nNew York State Teaching Certification \nChildhood Education, Grades 1-6 \n'>
# <LTTextBoxHorizontal(3) 36.520,627.015,174.358,638.055 'Standard First Aid and CPR \n'>
# <LTTextBoxHorizontal(4) 36.520,573.735,442.654,612.408 'EDUCATION \nMaster of Science for Teachers | State University of New York at Potsdam | Potsdam, NY \nSpecialization: Childhood Education | GPA: 3.99 \n'>
# <LTTextBoxHorizontal(5) 36.520,535.815,374.860,559.575 'Bachelor of Arts | State University of New York at Potsdam | Potsdam, NY \nMajor: Psychology | GPA: 3.24 \n'>
# <LTTextBoxHorizontal(6) 468.520,664.935,578.508,675.975 '   Anticipated May 2019 \n'>
# ...

# %%
from io import StringIO

from pdfminer.converter import TextConverter
from pdfminer.layout import LAParams
from pdfminer.pdfdocument import PDFDocument
from pdfminer.pdfinterp import PDFResourceManager, PDFPageInterpreter
from pdfminer.pdfpage import PDFPage
from pdfminer.pdfparser import PDFParser

def extract_pdf(pdf_file = r'C:\Users\Namita\OneDrive\Desktop\major_project\code\data\Teacher Resume Samples .pdf'):
    output_string = StringIO()
    with open(pdf_file, 'rb') as in_file:
        parser = PDFParser(in_file)
        doc = PDFDocument(parser)
        rsrcmgr = PDFResourceManager()
        device = TextConverter(rsrcmgr, output_string, laparams=LAParams())
        interpreter = PDFPageInterpreter(rsrcmgr, device)
        for page in PDFPage.create_pages(doc):
            interpreter.process_page(page)

    return output_string.getvalue()

# %%
extract_pdf(r'C:\Users\Namita\OneDrive\Desktop\major_project\code\data\Teacher Resume Samples .pdf')
# Out:
# 'Please note: Sample resumes are for reference only and should not be copied \n\nName \nStreet | City State, Zip | Phone | Email \n\nCERTIFICATION \nNew York State Teaching Certification \nChildhood Education, Grades 1-6 \n\nStandard First Aid and CPR \n\nEDUCATION \nMaster of Science for Teachers | State University of New York at Potsdam | Potsdam, NY \nSpecialization: Childhood Education | GPA: 3.99 \n\nBachelor of Arts | State University of New York at Potsdam | Potsdam, NY \nMajor: Psychology | GPA: 3.24 \n\n   Anticipated May 2019 \n\n    October 2017 \n\n   Anticipated May 2019 \n\n         May 2018 \n\nTEACHING EXPERIENCE \nStudent Teacher | Potsdam Elementary School | Potsdam, NY \n•  Conduct classroom activities for a second-grade class of 24 students by assisting with designing lesson plans and \n\n October 2017 – Present  \n\ninstructional delivery through an inclusive and diverse application to teaching \n\n•  Assist in lesson planning based on common core curriculum to p
# ...

# %%
from pdfminer.high_level import extract_pages
from pdfminer.layout import LTTextContainer
for page_layout in extract_pages(r"C:\Users\Namita\OneDrive\Desktop\major_project\code\data\Teacher Resume Samples .pdf"):
    for element in page_layout:
        if isinstance(element, LTTextContainer):
            print(element.get_text())
# Out:
# Please note: Sample resumes are for reference only and should not be copied
#
# Name
# Street | City State, Zip | Phone | Email
#
# CERTIFICATION
# New York State Teaching Certification
# Childhood Education, Grades 1-6
#
# Standard First Aid and CPR
#
# EDUCATION
# Master of Science for Teachers | State University of New York at Potsdam | Potsdam, NY
# Specialization: Childhood Education | GPA: 3.99
#
# Bachelor of Arts | State University of New York at Potsdam | Potsdam, NY
# Major: Psychology | GPA: 3.24
#
#    Anticipated May 2019
#
#     October 2017
#
#    Anticipated May 2019
#
#          May 2018
#
# TEACHING EXPERIENCE
# Student Teacher | Potsdam Elementary School | Potsdam, NY
# •  Conduct classroom activities for a second-grade class of 24 students by assisting with designing lesson plans and
#
#  October 2017 – Present
#
# instructional delivery through an inclusive and diverse application to teaching
#
# ...

# %%
from pdfminer.high_level import extract_pages
from pdfminer.layout import LTTextContainer, LTChar

for page_layout in extract_pages(r"C:\Users\Namita\OneDrive\Desktop\major_project\code\data\Teacher Resume Samples .pdf"):
    for element in page_layout:
        if isinstance(element, LTTextContainer):
            for text_line in element:
                # Use the get_text() method to obtain the text content
                text = text_line.get_text()
                print("Text:", text)
                print("---")
# Out:
# Text: Please note: Sample resumes are for reference only and should not be copied
#
# ---
# Text: Name
#
# ---
# Text: Street | City State, Zip | Phone | Email
#
# ---
# Text: CERTIFICATION
#
# ---
# Text: New York State Teaching Certification
#
# ---
# Text: Childhood Education, Grades 1-6
#
# ---
# Text: Standard First Aid and CPR
#
# ---
# Text: EDUCATION
#
# ---
# Text: Master of Science for Teachers | State University of New York at Potsdam | Potsdam, NY
#
# ---
# Text: Specialization: Childhood Education | GPA: 3.99
#
# ---
# Text: Bachelor of Arts | State University of New York at Potsdam | Potsdam, NY
#
# ---
# Text: Major: Psychology | GPA: 3.24
#
# ---
# Text:    Anticipated May 2019
#
# ---
# Text:     October 2017
#
# ---
# Text:    Anticipated May 2019
#
# ---
# Text:          May 2018
#
# ---
# Text: TEACHING EXPERIENCE
#
# ---
# Text: Student Teacher | Potsdam Elementary School | Potsdam, NY
#
# ---
# ...

# %%
from pdfminer.high_level import extract_text
text = extract_text(r'C:\Users\Namita\OneDrive\Desktop\major_project\code\data\Resume_SoftwareEng-Intern.pdf')
print(repr(text))
print(text)
# Out:
# 'Resume Sample (Software Engineering, pre-career)\n\nIm A. Spartan\nSan Jose, CA 95192 | (408) 555-5555 | imaspartan@gmail.com | linkedin/in/imaspartan\n\nOBJECTIVE: Seeking internship in full-stack development \n\nEDUCATION\nB.S., Software Engineering \nSan José State University, San José, CA, GPA: 3.8\n\nA.S., Computer Science \nDeAnza College, Cupertino, CA, GPA: 3.7\n\nTECHNICAL SKILLS\nProgramming: Java, Git, C, Python, PHP, JavaScript, CSS, Swift, Firebase, MySQL\nFrameworks: AngularJS, React\nOS: Unix/Linux, iOS\nRemote: Zoom, Google Meets, Slack, Discord\n\n         May 20XX\n\n          Jun 20XX\n\nRELATED EXPERIENCE\nSoftware Developer, Making Software, San Jose, CA \n•  Co-created company with two other engineers to make software application\n•  Manage iOS project and develop software, creating first iOS application to tell stories\n•  Oversee software application as project manager using Waterfall Agile process models\n•  Manage web development projects and maintain compa
# ...

# %%
import spacy

# Load English tokenizer, tagger, parser and NER
nlp = spacy.load("en_core_web_sm")

# Process whole documents
text = ("New York State")
doc = nlp(text)

# Analyze syntax
print("Noun phrases:", [chunk.text for chunk in doc.noun_chunks])
print("Verbs:", [token.lemma_ for token in doc if token.pos_ == "VERB"])

# Find named entities, phrases and concepts
for entity in doc.ents:
    print(entity.text, entity.label_)
# Out:
# Noun phrases: ['New York State']
# Verbs: []
# New York State GPE

# %%
import spacy 

nlp = spacy.load('en_core_web_sm') 

sentence = "Apple is looking at buying U.K. startup for $1 billion"

doc = nlp(sentence) 

for ent in doc.ents: 
	print(ent.text, ent.start_char, ent.end_char, ent.label_)
# Out:
# Apple 0 5 ORG
# U.K. 27 31 GPE
# $1 billion 44 54 MONEY

# %%
# doc2text

# %%
from docx import Document

def docx_to_text(file_path):
    doc = Document(file_path)
    text = ''
    for paragraph in doc.paragraphs:
        text += paragraph.text + '\n'
    return text

# Example usage
docx_file_path = r'C:\Users\Namita\OneDrive\Desktop\major_project\code\data\report minor project.docx'
text_content = docx_to_text(docx_file_path)
print(text_content)
# Out:
# A
# Project Report on
# Spotify Data Analysis
#                Submitted in Partial Fulfilment of the requirement for the Award of Degree of
# Bachelor of Computer Application
# Session 2023-24
#
# Submitted to
# Er. Vinay Kumar Vishwas
#  (Assistant Professor)
#
# Submitted by
# ANANYA SHUKLA
# (202110101130019)
# Under the guidance of
# Mr Amit Kumar Singh
#
# Department of Computer Science and Information System
# Shri Ramswaroop Memorial University Barabanki, Uttar Pradesh
# ACKNOWLEDGEMENT
#
# I would like to express my profound to Dr. Bineet Kumar Gupta , Head of Department of Computer Science and information Systems and to my faculty Er. Vinay Kumar Vishwas who gave me this opportunity to work on the project Spotify Data Analysis
# I would like to express my special thanks to my mentor Mr Amit Kumar Singh who gave me useful advice and suggestions which were really helpful to me during this project’s completion.
# ...

# %%
# ntlk prepocessing for cosing similarity

# %% [markdown]
# the NLTK library is commonly used for natural language processing (NLP) tasks, including text preprocessing, but it does not have built-in tools for text vectorization. Text vectorization involves converting text data into numerical vectors that can be used in machine learning models. For this task, other libraries like scikit-learn are typically used.

# %%
import nltk
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize
from nltk.stem import PorterStemmer, SnowballStemmer
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics.pairwise import cosine_similarity
from string import punctuation
# nltk.download("stopwords")
# nltk.download("punkt")

def preprocess_text(text):
    # remove punctations
    for char in punctuation:
        text = text.replace(char,'')
    
    # Lowercase the text
    text = text.lower()

    # Tokenize the text into words
    words = word_tokenize(text)

    # Remove stopwords
    stop_words = set(stopwords.words("english"))
    words = [word for word in words if word not in stop_words]

    # Stemming using Porter Stemmer
    stemmer = SnowballStemmer(language='english')
    words = [stemmer.stem(word) for word in words]

    # Join the words back into a single string
    processed_text = " ".join(words)

    return processed_text

def recommend(text1, text2):
    processed_text1 = preprocess_text(text1)
    processed_text2 = preprocess_text(text2)

    # print("Processed Text 1:", processed_text1)
    # print("Processed Text 2:", processed_text2)

    # Example Usage for Cosine Similarity
    vectorizer = TfidfVectorizer(stop_words="english")  # Automatically remove English stopwords
    vectors = vectorizer.fit_transform([processed_text1, processed_text2])

    similarity_score = cosine_similarity(vectors[0], vectors[1])[0][0]
    # print(f"Cosine Similarity: {similarity_score}")
    return {
        'recommend':similarity_score > .5,
        'similarity': similarity_score
    }




# Example Usage for Preprocessing
text1 = "This is a sample sentence for preprocessing."
text2 = "This is a sample sentence for"
recommend(text1, text2)
# Out:
# Processed Text 1: sampl sentenc preprocess
# Processed Text 2: sampl sentenc
# Cosine Similarity: 0.7092972666062739
# {'recommend': True, 'similarity': 0.7092972666062739}

# %% [markdown]
# In this example:
#
# The preprocess_text function handles basic text preprocessing using NLTK (lowercasing, tokenization, removing stopwords, and stemming).
# The example usage demonstrates how to preprocess two pieces of text using this function.
# The vectorization and cosine similarity calculation are then handled by scikit-learn's TfidfVectorizer and cosine_similarity.
